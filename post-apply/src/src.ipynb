# %%
import pandas as pd

# %%
dfa = pd.read_csv("../../apply/data/output/output_nn.csv")

# df = df[~(df.nn_relevant.astype(str) == "0")]

dfa = dfa[(dfa.gist.fillna("").str.contains("domestic"))]
# Out:
#       tracking_id                                               gist    year  \
# 14     2015-0002R  officer involved in a domestic disturbance out...  2015.0
# 29     2015-0017C  the complainant stated she called the police b...  2015.0
# 35     2015-0023C  officer was involved in a domestic incident wh...  2015.0
# 81    2015-0069.C  the complainant stated her cell phone had been...  2015.0
# 106    2015-0093R  officer failed to document a domestic violence...  2015.0
# ...           ...                                                ...     ...
# 9690  2017-0587-R  (district) accused refused to take action at a...  2017.0
# 9691  2017-0588-R  complainant alleged accused changed to signal ...  2017.0
# 9692  2017-0589-R  the officers failed to document a domestic inc...  2017.0
# 9707  2017-0604-P  officers did not investigate incident involvin...  2017.0
# 9715  2017-0612-P  the complainant stated that the sgt. smothers ...  2017.0
#
#       nn_relevant
# 14              1
# ...

# %%
dfb = pd.read_csv("")
