# %%
import pandas as pd

# %%
def read_table_from_webiste():
    df = pd.read_csv("../data/input/NOPD_Misconduct_Complaints_20250403.csv")
    return df 


dfa = read_table_from_webiste()

dfa

### only keep tracking number, complainant gender, complainant ethnicity and complainant age from this table
### then merge
# Out:
#          Incident Type Complaint Tracking Number Date Complaint Occurred  \
# 0     Public Initiated               2016-0001-P              2016-01-01
# 1     Public Initiated               2016-0002-P              2016-01-02
# 2     Public Initiated               2016-0002-P              2016-01-02
# 3     Public Initiated               2016-0009-P              2016-01-04
# 4     Public Initiated               2016-0006-P              2016-12-30
# ...                ...                       ...                     ...
# 9152    Rank Initiated               2025-0129-R              2025-03-15
# 9153  Public Initiated               2025-0133-N              2025-03-15
# 9154  Public Initiated               2025-0125-P              2025-03-21
# 9155    Rank Initiated               2025-0138-R              2025-03-28
# 9156  Public Initiated               2025-0135-N              2025-03-05
#
#      Date Complaint Received by NOPD (PIB)  \
# 0                               2016-01-01
# ...

# %%
def read_table_from_llead():
    df = pd.read_csv("../data/input/new_orleans_pd_cprr_2005_2023.csv")
    return df 

dfb = read_table_from_llead()

dfb
# Out:
#               'FDI #     'Incident Type 'Investigation Status  \
# 0      '2024- 0128-P  'Public Initiated              'Initial
# 1      '2024- 0127-P  'Public Initiated               'Active
# 2      '2024- 0126-R    'Rank Initiated              'Initial
# 3      '2024- 0125-P  'Public Initiated              'Initial
# 4      '2024- 0125-P  'Public Initiated              'Initial
# ...              ...                ...                   ...
# 29661  '2010- 0954-C  'Public Initiated            'Completed
# 29662  '2010- 0954-C  'Public Initiated            'Completed
# 29663  '2010- 0954-C  'Public Initiated            'Completed
# 29664  '2010- 0953-N  'Public Initiated            'Completed
# 29665  '2010- 0953-N  'Public Initiated            'Completed
#
#       'Accused Employee ID 'Accused First  'Accused Last 'Allegation #  \
# 0                  '026459        'Paloma  'Ramos- Tapia        '33483
# 1                  '006608         'Chris        'Robert        '33480
# ...

# %%
dfc
